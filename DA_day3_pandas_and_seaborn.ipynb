# %% [markdown]
# Pandas:
# -used for data manipulation(data cleaning,organizing data)
# -Creates datafarmes from excel,csv,txt,DBs
# -Data frame(rows and coloumns readable by python)
# -Data cleaning by dropping or replacing with mean
# -visulize the data

# %%
import pandas as pd

# %%
import pandas as pd
names=["divya","bhavani","kadiyam"]
index=[40,50,69]
ser1=pd.Series(names,index)
print(ser1)
# Out:
# 40      divya
# 50    bhavani
# 69    kadiyam
# dtype: object

# %% [markdown]
# importing files:
# -for csv and txt:read_csv("file path")
# -for excel :read _excel("file path")

# %%
df=pd.read_csv("/content/csv1.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-df3f4cac920b> in <cell line: 1>()
# ----> 1 df=pd.read_csv("/content/csv1.csv")
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-7bf98a8691b5> in <cell line: 1>()
# ----> 1 f.head(10)
#
# NameError: name 'f' is not defined

# %%
df.tail(10)
# Out:
#               Date  Day     Month  Year  Customer_Age             Age_Group  \
# 113026  30-12-2021   30  December  2021            30  Young Adults (25-34)
# 113027  30-12-2021   30  December  2021            36        Adults (35-64)
# 113028  30-12-2021   30  December  2021            46        Adults (35-64)
# 113029  31-12-2021   31  December  2021            32  Young Adults (25-34)
# 113030  31-12-2021   31  December  2021            36        Adults (35-64)
# 113031  31-12-2021   31  December  2021            52        Adults (35-64)
# 113032  31-12-2021   31  December  2021            25  Young Adults (25-34)
# 113033  31-12-2021   31  December  2021            26  Young Adults (25-34)
# 113034  31-12-2021   31  December  2021            33  Young Adults (25-34)
# 113035  31-12-2021   31  December  2021            44        Adults (35-64)
#
#         Age_Group_NUMBER Customer_Gender         Country Product_Category  \
# ...

# %%
dft=pd.read_csv("/content/heart text1.txt")

# %%
dft.head(10)
# Out:
#   age\tanaemia\tcreatinine_phosphokinase\tdiabetes\tejection_fraction\thigh_blood_pressure\tplatelets\tserum_creatinine\tserum_sodium\tsex\tsmoking\ttime\tDEATH_EVENT
# 0  75\t0\t582\t0\t20\t1\t265000\t1.9\t130\t1\t0\t...
# 1  55\t0\t7861\t0\t38\t0\t263358.03\t1.1\t136\t1\...
# 2  65\t0\t146\t0\t20\t0\t162000\t1.3\t129\t1\t1\t...
# 3  50\t1\t111\t0\t20\t0\t210000\t1.9\t137\t1\t0\t...
# 4  65\t1\t160\t1\t20\t0\t327000\t2.7\t116\t0\t0\t...
# 5  90\t1\t47\t0\t40\t1\t204000\t2.1\t132\t1\t1\t8\t1
# 6  75\t1\t246\t0\t15\t0\t127000\t1.2\t137\t1\t0\t...
# 7  60\t1\t315\t1\t60\t0\t454000\t1.1\t131\t1\t1\t...
# 8  65\t0\t157\t0\t65\t0\t263358.03\t1.5\t138\t0\t...
# 9  80\t1\t123\t0\t35\t1\t388000\t9.4\t133\t1\t1\t...

# %%
dft.tail(10)
# Out:
#     age\tanaemia\tcreatinine_phosphokinase\tdiabetes\tejection_fraction\thigh_blood_pressure\tplatelets\tserum_creatinine\tserum_sodium\tsex\tsmoking\ttime\tDEATH_EVENT
# 289  90\t1\t337\t0\t38\t0\t390000\t0.9\t144\t0\t0\t...
# 290  45\t0\t615\t1\t55\t0\t222000\t0.8\t141\t0\t0\t...
# 291  60\t0\t320\t0\t35\t0\t133000\t1.4\t139\t1\t0\t...
# 292  52\t0\t190\t1\t38\t0\t382000\t1\t140\t1\t1\t25...
# 293  63\t1\t103\t1\t35\t0\t179000\t0.9\t136\t1\t1\t...
# 294  62\t0\t61\t1\t38\t1\t155000\t1.1\t143\t1\t1\t2...
# 295  55\t0\t1820\t0\t38\t0\t270000\t1.2\t139\t0\t0\...
# 296  45\t0\t2060\t1\t60\t0\t742000\t0.8\t138\t0\t0\...
# 297  45\t0\t2413\t0\t38\t0\t140000\t1.4\t140\t1\t1\...
# 298  50\t0\t196\t0\t45\t0\t395000\t1.6\t136\t1\t1\t...

# %%
df=pd.read_csv("/content/csv2.csv",sep=",")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-cab446feaeab> in <cell line: 1>()
# ----> 1 df=pd.read_csv("/content/csv2.csv",sep=",")
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
df.head(10)
# Out:
#   version  season  episode_number_overall  episode               title  \
# 0      US       1                       1        1    And So It Begins
# 1      US       1                       2        2     Of Wolf and Man
# 2      US       1                       3        3  The Talons of Fear
# 3      US       1                       4        4             Stalked
# 4      US       1                       5        5       Winds of Hell
# 5      US       1                       6        6      Rain of Terror
# 6      US       1                       7        7          The Hunger
# 7      US       1                       8        8    After the Rescue
# 8      US       1                       9        9          The Freeze
# 9      US       1                      10       10    Brokedown Palace
#
#      air_date  viewers                                              quote  \
# 0  18-06-2015    1.582  I went to the woods because I wished to live d...
# ...

# %%
print(df.shape)#get the no of rows and coloumns
print(df.shape[0])#get the no of rows only
print(df.shape[1])#get the no of coloumns only
# Out:
# (120, 13)
# 120
# 13

# %% [markdown]
# accessing data
# loc-accepts column names and index
# iloc-accepts only index

# %%
print(df.columns)
# Out:
# Index(['version', 'season', 'episode_number_overall', 'episode', 'title',
#        'air_date', 'viewers', 'quote', 'author', 'imdb_rating', 'n_ratings',
#        'n_remaining', 'day_start'],
#       dtype='object')

# %%
print(df[2:5])#to access
# Out:
#   version  season  episode_number_overall  episode               title  \
# 2      US       1                       3        3  The Talons of Fear
# 3      US       1                       4        4             Stalked
# 4      US       1                       5        5       Winds of Hell
#
#      air_date  viewers                                              quote  \
# 2  02-07-2015    1.864  Extinction is the rule. Survival is the except...
# 3  09-07-2015    2.082  Hunger, love, pain, fear are some of those inn...
# 4  16-07-2015    2.082    The strong survive, but the courageous triumph.
#
#             author  imdb_rating  n_ratings  n_remaining  day_start
# 2       Carl Sagan          7.7        104          NaN        NaN
# 3  Albert Einstein          7.7        104          NaN        NaN
# 4    Michael Scott          7.6         99          NaN        NaN

# %%
print(df.loc[2:5],"Names")
# Out:
#   version  season  episode_number_overall  episode               title  \
# 2      US       1                       3        3  The Talons of Fear
# 3      US       1                       4        4             Stalked
# 4      US       1                       5        5       Winds of Hell
# 5      US       1                       6        6      Rain of Terror
#
#      air_date  viewers                                              quote  \
# 2  02-07-2015    1.864  Extinction is the rule. Survival is the except...
# 3  09-07-2015    2.082  Hunger, love, pain, fear are some of those inn...
# 4  16-07-2015    2.082    The strong survive, but the courageous triumph.
# 5  23-07-2015    2.181  Extraordinary people survive under the most te...
#
#              author  imdb_rating  n_ratings  n_remaining  day_start
# 2        Carl Sagan          7.7        104          NaN        NaN
# 3   Albert Einstein          7.7        104          NaN        NaN
# ...

# %%
print(df.iloc[2:5])
# Out:
#   version  season  episode_number_overall  episode               title  \
# 2      US       1                       3        3  The Talons of Fear
# 3      US       1                       4        4             Stalked
# 4      US       1                       5        5       Winds of Hell
#
#      air_date  viewers                                              quote  \
# 2  02-07-2015    1.864  Extinction is the rule. Survival is the except...
# 3  09-07-2015    2.082  Hunger, love, pain, fear are some of those inn...
# 4  16-07-2015    2.082    The strong survive, but the courageous triumph.
#
#             author  imdb_rating  n_ratings  n_remaining  day_start
# 2       Carl Sagan          7.7        104          NaN        NaN
# 3  Albert Einstein          7.7        104          NaN        NaN
# 4    Michael Scott          7.6         99          NaN        NaN

# %%
print(df.iloc[2:5,:3])#iloc[row range,column range]=>index
# Out:
#   version  season  episode_number_overall
# 2      US       1                       3
# 3      US       1                       4
# 4      US       1                       5

# %%
df=pd.read_csv("/content/grades_withnulls.csv")

# %%
df.isnull().head(7)
# Out:
#    Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 0  False     False  False  False  False  False   False
# 1  False     False  False  False  False  False   False
# 2  False     False  False  False  False  False   False
# 3  False     False  False  False   True  False   False
# 4  False     False  False  False  False  False   False
# 5  False     False  False  False  False  False   False
# 6  False     False  False  False  False  False   False

# %%
df.isnull()
# Out:
#     Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 0   False     False  False  False  False  False   False
# 1   False     False  False  False  False  False   False
# 2   False     False  False  False  False  False   False
# 3   False     False  False  False   True  False   False
# 4   False     False  False  False  False  False   False
# 5   False     False  False  False  False  False   False
# 6   False     False  False  False  False  False   False
# 7   False     False  False  False  False  False   False
# 8   False     False   True  False  False  False   False
# 9   False     False   True  False  False  False   False
# 10  False     False   True  False  False  False   False
# 11  False     False  False  False  False  False   False
# 12  False     False  False  False  False  False   False
# 13  False     False  False  False  False  False   False
# 14  False     False  False  False  False  False   False
# 15  False     False  False  False  False  False   False
# ...

# %%
df.isnull().sum()#to sum all nulls
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bdbf056d279f> in <cell line: 1>()
# ----> 1 df.isnull().sum()#to sum all nulls
#
# NameError: name 'df' is not defined

# %%
df.isnull().sum().sum()#to view total nulls
# Out:
# 4

# %% [markdown]
# dropping

# %%
dfc=df.dropna()#dropping all the rows with nulls

# %% [markdown]
# cleaning wir

# %%
dfc
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
dfc1=df.fillna(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-326d9a0d6551> in <cell line: 1>()
# ----> 1 dfc1=df.fillna(3)
#
# NameError: name 'df' is not defined

# %%
dfc1
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   3.0     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   3.0   9.1   9.9    A+       1
# 9   Rajini        M   3.0   9.1   9.3     A       0
# 10   Kiran        V   3.0   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %% [markdown]
# cleaning with mean

# %%
m=df['SEM2'].mean()
print(m)
# Out:
# 9.0

# %%
dfc1=df.fillna(m)
print(dfc1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-57797617b74f> in <cell line: 1>()
# ----> 1 dfc1=df.fillna(m)
#       2 print(dfc1)
#
# NameError: name 'df' is not defined

# %%
dropped=dfc1.drop_duplicates()
print(dropped)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   9.0     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   9.0   9.1   9.9    A+       1
# 9   Rajini        M   9.0   9.1   9.3     A       0
# 10   Kiran        V   9.0   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %% [markdown]
# columns

# %%
dfc1.rename(columns={"grade":"GPA"},inplace = True) #df.rename(columns = {old:new})
dfc1
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   9.0     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   9.0   9.1   9.9    A+       1
# 9   Rajini        M   9.0   9.1   9.3     A       0
# 10   Kiran        V   9.0   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
dfc1['Avg_score']=(dfc1['SEM1'] + dfc1['SEM2']+dfc1['SEM3'])/3 #df['newcol']=Values
dfc1.head()
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed  Avg_score
# 0     Joe        K   9.8  10.0   9.9    A+       1   9.900000
# 1  Rajesh        M   8.9   9.1   9.3     A       1   9.100000
# 2  Kissan        V   9.9   9.8  10.0     A       0   9.900000
# 3    Mary        N   7.7   8.0   9.0     B       0   8.233333
# 4    Jeen        K   9.8   9.1   9.9    A+       1   9.600000

# %%
dfc1[['SEM1','SEM2']].plot.line()
# Out:
# <Axes: >

# %%
dfc1.plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %% [markdown]
# seaborn

# %%
import seaborn as sns

# %%
pl=sns.relplot(x='Names',y='SEM1',data=dfc1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-056cdd83022b> in <cell line: 1>()
# ----> 1 pl=sns.relplot(x='Names',y='SEM1',data=dfc1)
#
# NameError: name 'dfc1' is not defined

# %%
sns.relplot(data=df,x="SEM2",y="SEM1",col="Placed")

# %% [markdown]
# problem
# -load diabetes.csv
# -create replot
# -with index numbers as xaxis in y axis class as columns
# hue difference

# %%
df1=pd.read_csv("/content/csv2.csv")
df1
# Out:
#     version  season  episode_number_overall  episode               title  \
# 0        US       1                       1        1    And So It Begins
# 1        US       1                       2        2     Of Wolf and Man
# 2        US       1                       3        3  The Talons of Fear
# 3        US       1                       4        4             Stalked
# 4        US       1                       5        5       Winds of Hell
# ..      ...     ...                     ...      ...                 ...
# 115      US      10                     107        7           Aftermath
# 116      US      10                     108        8         Infestation
# 117      US      10                     109        9          Splintered
# 118      US      10                     110       10                Rats
# 119      US      10                     111       11        By Any Means
#
#        air_date  viewers                                              quote  \
# ...

# %%
df1['index_no.s']=range(1,769)
df1.head()
# Out:
#    preg  plas  pres  skin  insu  mass   pedi  age            class  index_no.s
# 0     6   148    72    35     0  33.6  0.627   50  tested_positive           1
# 1     1    85    66    29     0  26.6  0.351   31  tested_negative           2
# 2     8   183    64     0     0  23.3  0.672   32  tested_positive           3
# 3     1    89    66    23    94  28.1  0.167   21  tested_negative           4
# 4     0   137    40    35   168  43.1  2.288   33  tested_positive           5

# %%
df1=pd.read_csv("/content/diabetcsv.csv")
df1
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
sns.relplot(data=df1,x="index_no.s",y="age",col="class")

# %% [markdown]
# inbuilt data types in python
# tips
# dowjones
# fmri
# dots
# health exp
# -to load these data load_dataset("datatype name")

# %%
tips=sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
dowjones=sns.load_dataset("dowjones")
dowjones.head()
# Out:
#         Date  Price
# 0 1914-12-01  55.00
# 1 1915-01-01  56.55
# 2 1915-02-01  56.00
# 3 1915-03-01  58.30
# 4 1915-04-01  66.45

# %%
fmri=sns.load_dataset("fmri")
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
dots=sns.load_dataset("dots")
dots.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
healthexp=sns.load_dataset("healthexp")
healthexp.head()
# Out:
#    Year        Country  Spending_USD  Life_Expectancy
# 0  1970        Germany       252.311             70.6
# 1  1970         France       192.143             72.2
# 2  1970  Great Britain       123.993             71.9
# 3  1970          Japan       150.437             72.0
# 4  1970            USA       326.961             70.9

# %%
sns.relplot(data=tips,x="total_bill",y="tip")

# %%
sns.lineplot(data=tips,x="total_bill",y="tip",hue="smoker")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lineplot(data=tips,x="total_bill",y="tip",hue="time")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lineplot(data=tips,x="total_bill",y="tip",hue="day")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(data=tips,x="total_bill",y="tip",hue="day")

# %% [markdown]
# style
# uses different markers for different category

# %%
sns.relplot(data=tips,x="total_bill",y="tip",hue="smoker",style="time")

# %% [markdown]
# # total palette pastel bright dark muted colurblind deep

# %%
sns.relplot(data=tips,x="total_bill",y="tip",hue="smoker",style="time",palette="bright")

# %%
sns.lineplot(data=dowjones,x="Date",y="Price")
# Out:
# <Axes: xlabel='Date', ylabel='Price'>

# %%
sns.relplot(data=dowjones,x="Date",y="Price",kind="line")

# %% [markdown]
# type pointers=no of sec
# region=brain loc

# %%
sns.relplot(data=fmri,x="timepoint",y="signal")

# %%
sns.catplot(data=tips,x="total_bill",y="tip")

# %%
sns.catplot(data=dowjones,x="Date",y="Price",kind="violin")

# %%
sns.catplot(data=tips,x="total_bill",y="time",kind="violin")

# %% [markdown]
# linear regression
# lmplot(function)

# %%
sns.lmplot(x="size",y="tip",data=tips)

# %% [markdown]
# web scrapping
# -scrapping data from websites
# unstructured in html
# convertible into spreadsheets
# major websites havetheir APIs for web scrapping
# scrapper
